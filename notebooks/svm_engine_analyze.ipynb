# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
from notebooks.engines.sailor_data_engineer import RouteGenConfig, SailorDataEngineer

_config = RouteGenConfig.from_env()
engineer = SailorDataEngineer(_config, cache_key='test_model', route_description="flight agency admin panel")

route_context = await engineer.generate_data(20, 200)

# %%
from sailor import RouteDocumentor
from sklearn.model_selection import train_test_split
from sailor.types.route_context import NavigationContext

if route_context is None:
	raise ValueError("route_context must be generated first")

train_sessions, test_sessions = train_test_split(route_context.sessions, test_size=0.2, random_state=14)
train_context = NavigationContext(routes=route_context.routes, sessions=train_sessions)

documentor = RouteDocumentor(train_context)
labels = documentor.fit_transform()

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english')),
    ('svc', LinearSVC(class_weight='balanced', max_iter=2000)),
])

pipeline.fit(documentor.documents, labels)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(stop_words='english')),
#                 ('svc', LinearSVC(class_weight='balanced', max_iter=2000))])

# %%
from sklearn.metrics import classification_report

test_queries = [s.context for s in test_sessions]
_predictions = pipeline.predict(test_queries)

_targets = documentor.transform([s.target for s in test_sessions])
print(classification_report(_targets, _predictions, target_names=documentor.labels_))
# Out:
#                    precision    recall  f1-score   support
#
# admin-dashboard-5       1.00      1.00      1.00         7
#   airport-info-10       0.69      0.85      0.76        13
# booking-details-2       0.89      0.94      0.91        17
#    deals-offers-9       0.83      0.50      0.62        10
#   flight-search-1       1.00      0.80      0.89        15
#   flight-status-6       0.73      1.00      0.84         8
#     help-center-8       0.83      1.00      0.91        10
# loyalty-program-7       1.00      0.91      0.95        11
# payment-process-3       1.00      0.93      0.96        14
#    user-profile-4       0.80      0.80      0.80         5
#
#          accuracy                           0.87       110
#         macro avg       0.88      0.87      0.87       110
#      weighted avg       0.89      0.87      0.87       110

# %%
from typing import List
import numpy as np

from sailor.types.route_context import RouteContextResult

def _scored_routes(scores) -> List[RouteContextResult]:
    sorted_index = np.argsort(scores)[::-1]
    routes: List[RouteContextResult] = []
    for i in sorted_index:
      route = documentor.inverse_transform(i)
      if route is not None:
        route = route.copy_with_score(float(scores[i]))
        routes.append(route)
    return routes

def predict(query: str) -> List[RouteContextResult]:
    if not query.strip():
        return []

    scores = pipeline.decision_function([query])[0]
    return _scored_routes(scores)

# %%
routes = predict("I want to book a flight from São Paulo to New York")[:5]
for route in routes:
  print(f"Path: {route.path}, Score: {route.score:.2f}")
  print(f"Context: {route.context}")
# Out:
# Path: /flights/status/{flightNumber}, Score: -0.42
# Context: flights status {flightNumber} flight status flight status track flight flight tracking check flight status User clicked link email check flight status User wants check status flight User entered flight number manually User wants check status flight User wants find flight time User wants status flight User clicked link track specific flight User wants find gate information flight User wants know reason delay flight User wants check status flight User trying locate flight map User clicked Track button flight path User wants flight affected air traffic control User wants find departure time flight User wants check status flight User wants check flight time connecting flight User clicked Check Status button entering flight number User wants check arrival time flight User tapped search icon entering flight number User voice command search flight status User wants check gate changes flight User wants confirm flight landed User wants flight canceled User wants find flight duration flight User wants track flight User scanned boarding pass check flight status User wants check flight delayed weather User wants check flight changed route User autofill enter flight number User selected flight recent searches User clicked flight alert notification User wants find arrival gate flight
# Path: /flights/search, Score: -0.64
# Context: flights search flight search flights availability find flights flight search User searching minute flight deals User wants navigate flight search page main menu User wants navigate flight search page find flights specific airlines User wants navigate flight search find flights peak season User searches flights San Francisco Tokyo departing April User searching flights adventure trip User searching flights Seattle Denver User searches flights New York Los Angeles January User searches weekend flights Chicago Miami User searching flights Africa User changes currency flight prices User wants navigate flight search find flights meal options User searching flights Dallas Houston User filters flight search results airline User searching flights flexible dates User searching flights South America User uses calendar select different departure return dates User wants navigate flight search page find flights onboard entertainment User searches way flights Chicago Miami March User wants navigate flight search find flights power outlets User wants navigate flight search filter shortest flights User searches flights Melbourne Singapore December User scrolls flight search results page User wants navigate flight search page find flights package deal User changes number passengers flight search User wants navigate flight search page find flights free cancellation User wants navigate flight search find way tickets User searches flights Madrid Bangkok October User searches flights Los Angeles Chicago November November User searching flights Boston Atlanta User searches flights San Francisco Sydney March March User searching flights San Francisco Tokyo User searching direct flights User sorts flight results price User searches flights Rome Buenos Aires June User searches flights Miami New York October User searching flights romantic getaway User clicks Modify Search change search criteria User searches flights specific stopover duration User expands Options section specify preferred airlines User searches flights Seattle Denver User searching round trip flights Chicago Miami User wants navigate flight search page check connecting flights User wants navigate flight search find flights based specific time day User searches flights Sydney Auckland November November User wants navigate flight search find flights offer mileage points User clicks Find Flights button modifying search criteria User wants navigate flight search page find flights Wi Fi User clicks Search Flights button entering origin destination User wants navigate flight search find flights allow pets User navigates search form results page User searching flights Asia User searches flights San Diego Seattle December User searches flights Berlin Cape Town September September User wants navigate flight search check business class flights User clicks flight result view details User searching flights Europe User wants navigate flight search page book flights group User searching flights weekend getaway User expands Advanced Options section baggage preferences User searches flights Houston Orlando August User searching flights London Paris User searches flights Boston Atlanta June User searching flights family vacation User wants navigate flight search compare prices User selects preferred seating class economy business User wants navigate flight search promotional banner User searches flights specific airline alliance User searches flights Paris Tokyo User selects Nearby Airports option origin User searching flights Australia User searches flights London Dubai April
# Path: /loyalty/program, Score: -0.64
# Context: loyalty program loyalty program rewards membership loyalty program rewards program transfer points member credit cards affiliated loyalty program Find loyalty programs offer travel rewards Find bonus points offers signing User clicked Learn button specific benefit Search elite status qualifications Clicked Terms Conditions link sort feature program rewards Find partner programs Clicked link view loyalty program profile redeem points rewards Find current promotions loyalty program User clicked link Update Contact Information Submitted enrollment form earn points Scrolled page view footer links Search gift card redemption options Clicked Forgot Password link login cancel loyalty program membership Clicked Enroll button loyalty program Searching family loyalty programs Clicked Join button specific program detail page Search expiry points Looking information earning points loyalty program Clicked View Details Silver Rewards program Clicked Contact Support loyalty program assistance types rewards offered Clicked Works video tutorial Navigated FAQ section loyalty program page program selector dropdown view different programs Find airline loyalty programs Selected Compare Programs option Clicked Account view loyalty program details Check current points balance
# Path: /admin/dashboard, Score: -0.67
# Context: admin dashboard admin dashboard admin panel system admin admin dashboard Searched license usage manage software licenses Searched error messages troubleshoot system issues Clicked Notifications icon view recent alerts Navigated dashboard monitor resource utilization Looked system uptime measure system reliability Clicked Configuration button change system settings Clicked Settings icon configure system parameters Clicked Updates link check system updates Looked queue lengths monitor message queue performance Searched system events analyze system behavior Navigated dashboard assess overall system performance Clicked System Health widget drill server status Looked database connections monitor database performance Looked response times identify slow operations Looked memory usage ensure system stability Searched API usage analyze API traffic Searched recent alerts identify potential issues Clicked Logs button view system logs Looked storage capacity manage data storage Navigated dashboard monitor status background jobs Searched job execution times optimize job scheduling Navigated dashboard check failed processes Looked CPU usage identify performance bottlenecks Navigated dashboard monitor system resources Looked specific user activity metrics dashboard Looked system logs troubleshoot issues Clicked Reports button generate system report Navigated dashboard check status data replication Searched resource allocation optimize system resources Clicked System Info link view system details Searched audit trails track user actions Searched failed login attempts identify security threats Clicked User Management link manage user accounts Clicked Backup button initiate system backup
# Path: /booking/details/{bookingId}, Score: -0.68
# Context: booking details {bookingId} booking details flight booking manage booking view booking booking details User searched flight number destination access booking details User navigated travel insurance confirmation page view flight booking details User clicked View Booking Details making changes booking User searched departure city arrival city date find booking details User accessed booking details saved link computer User searched booking ID view flight details User entered booking ID check baggage allowance User clicked View Itinerary button completing booking process User clicked link chat support window view booking details User clicked View Booking button receiving reminder email User confirmation number departure date retrieve booking details User searched flight route CDG JFK travel date details User searched loyalty program number booking date find booking details User looked booking details ticket number surname User searched flight number date access booking details User clicked link survey email view booking details User searched group booking reference surname find booking details User accessed booking details account dashboard User navigated partner website booking hotel wants flight details User navigated party travel site view booking details User navigated previous booking confirmation page view current booking details User searched email address find booking details User searched family booking reference date birth find booking details User searched passport number flight date retrieve booking details User searched Smith booking ID find booking details User searched company booking code employee ID find booking details User clicked promotional offer link view booking details potential upgrade User clicked link email confirmation view booking details User searched booking reference access booking details User navigated car rental booking confirmation flight details
